# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMe

# %%
human_msg=HumanMessage(
    content="Hello!",
    name="alice",
    id="msg_123"
)
response=model.invoke([human_msg])
response
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 37, 'total_tokens': 47, 'completion_time': 0.027812336, 'completion_tokens_details': None, 'prompt_time': 0.001925285, 'prompt_tokens_details': None, 'queue_time': 0.051906045, 'total_time': 0.029737621}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbd64-ca7e-7f01-aedf-8218317eaad3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 10, 'total_tokens': 47})

# %%
system_msg=SystemMessage("you are a coding trainer")
messages=[
    system_msg,
    HumanMessage("How do i get into ai ml")
]
response=model.invoke(messages)
print(response.content)
# Out:
# Getting into AI and ML can be an exciting and rewarding career path. Here's a step-by-step guide to help you get started:
#
# **Prerequisites:**
#
# 1. **Mathematics**: Linear Algebra, Calculus, Probability, and Statistics are essential mathematical concepts used in AI and ML.
# 2. **Programming skills**: Python is the most popular language used in AI and ML. Familiarity with Python and its libraries (e.g., NumPy, Pandas, scikit-learn) is necessary.
# 3. **Data structures and algorithms**: Understanding data structures (e.g., arrays, linked lists, trees) and algorithms (e.g., sorting, searching) is crucial.
#
# **Step 1: Learn the basics**
#
# 1. **Online courses**:
# 	* Andrew Ng's Machine Learning course on Coursera
# 	* Stanford University's Natural Language Processing with Deep Learning Specialization on Coursera
# 	* Machine Learning with Python on DataCamp
# 2. **Books**:
# 	* "Machine Learning" by Andrew Ng and Michael I. Jordan
# ...

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage

messages=[
    SystemMessage("you are a philoshopher"),
    HumanMessage("explain some theory on thinking")
]
response=model.invoke(messages)
response.content
# Out:
# "As a philosopher, I'd like to delve into the realm of thinking and explore some fascinating theories. Here are a few:\n\n1. **The Computational Theory of Mind**: This theory, proposed by philosophers like Alan Turing and Hilary Putnam, suggests that the human mind can be understood as a computational system. According to this view, thinking is a process of information processing, where the brain receives inputs, performs calculations, and produces outputs. This perspective implies that thinking is a mechanical, algorithmic process that can be replicated by machines.\n\n2. **The Global Workspace Theory**: This theory, developed by psychologist Bernard Baars, posits that the mind has a global workspace where information from various sensory and cognitive systems is integrated. Thinking, in this view, involves the global workspace's ability to selectively focus attention, retrieve memories, and manipulate information to solve problems or make decisions. This theory highlights the impor
# ...

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model=init_chat_model("groq:llama-3.3-70b-versatile")
